# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# C:\Users\kaust\AppData\Local\Temp\ipykernel_21792\1046590060.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
#cleanupdata

# %%
#Only want US racer

# %%
#step1 show 50 mi or 50 km

# %%
df[df['Event distance/length']=='50mi']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
df[((df['Event distance/length'].isin(['50km', '50mi'])) & (df['Year of event'] == 2020))]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %%
df[df['Event name'].str.contains('\(USA\)')]
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %%
#combininng all the filters together

# %%
df2=df[(df['Event distance/length'] == '50mi') & (df['Event distance/length'].isin(['50km', '50mi'])) & (df['Year of event'] == 2020) & (df['Event name'].str.contains('USA'))]

# %%
df2.head(10)
# Out:
#          Year of event Event dates                       Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542139           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542140           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542141           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542142           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542143           2020  01.02.2020  Elephant Mountain 50 Mile (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10           8:51:11 h
# ...

# %%
df2.shape
# Out:
# (5699, 13)

# %%
#removing usa from event name

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 2542134    Elephant Mountain 50 Mile
# 2542135    Elephant Mountain 50 Mile
# 2542136    Elephant Mountain 50 Mile
# 2542137    Elephant Mountain 50 Mile
# 2542138    Elephant Mountain 50 Mile
#                       ...
# 2757274    Old Cascadia 50 Mile Race
# 2757275    Old Cascadia 50 Mile Race
# 2757276    Old Cascadia 50 Mile Race
# 2757277    Old Cascadia 50 Mile Race
# 2757278    Old Cascadia 50 Mile Race
# Name: Event name, Length: 5699, dtype: object

# %%
df2['Event name']=df2['Event name'].str.split('(').str.get(0)
# Out:
# C:\Users\kaust\AppData\Local\Temp\ipykernel_11368\2517910487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Event name']=df2['Event name'].str.split('(').str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates                  Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10           8:51:11 h
# 2542135                  50mi                         10          11:37:15 h
# 2542136                  50mi                         10          11:59:00 h
# 2542137                  50mi                         10          12:04:40 h
# 2542138                  50mi                         10          12:26:20 h
#
#             Athlete club Athlete country  Athlete year of birth  \
# ...

# %%
#cleaning up age

# %%
df2['Athlete_age']=2020-df2['Athlete year of birth']
# Out:
# C:\Users\kaust\AppData\Local\Temp\ipykernel_11368\817233726.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete_age']=2020-df2['Athlete year of birth']

# %%
#remove h from athlete performance

# %%
df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# 2542134     8:51:11
# 2542135    11:37:15
# 2542136    11:59:00
# 2542137    12:04:40
# 2542138    12:26:20
#              ...
# 2757274    16:05:34
# 2757275    16:22:12
# 2757276    16:46:54
# 2757277    16:46:56
# 2757278    17:51:56
# Name: Athlete performance, Length: 5699, dtype: object

# %%
df2['Athlete performance']=df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# C:\Users\kaust\AppData\Local\Temp\ipykernel_11368\2382045920.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete performance']=df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(100)
# Out:
#          Year of event Event dates                  Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile
# ...                ...         ...                         ...
# 2548835           2020  25.01.2020  Arches Ultra 50 Mile Race
# 2548836           2020  25.01.2020  Arches Ultra 50 Mile Race
# 2548837           2020  25.01.2020  Arches Ultra 50 Mile Race
# 2548838           2020  25.01.2020  Arches Ultra 50 Mile Race
# 2548839           2020  25.01.2020  Arches Ultra 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10             8:51:11
# ...

# %%
df2.head(0)
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete club, Athlete country, Athlete year of birth, Athlete gender, Athlete age category, Athlete average speed, Athlete ID, Athlete_age]
# Index: []

# %%
# drop columns : Athlete Club, Athlete Country , Athelete year of birth , Athlete Age Category

# %%
df2 = df2.drop(['Athlete club','Athlete country','Athlete year of birth', 'Athlete age category'], axis = 1)

# %%
df2.head(10)
# Out:
#          Year of event Event dates                  Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542139           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542140           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542141           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542142           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542143           2020  01.02.2020  Elephant Mountain 50 Mile
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10             8:51:11
# 2542135                  50mi                         10            11:37:15
# ...

# %%
#clean up null values

# %%
df2.isna().sum()
# Out:
# Year of event                 0
# Event dates                   0
# Event name                    0
# Event distance/length         0
# Event number of finishers     0
# Athlete performance           0
# Athlete gender                0
# Athlete average speed         0
# Athlete ID                    0
# Athlete_age                  42
# dtype: int64

# %%
df2[df2['Athlete_age'].isna()==1]
# Out:
#          Year of event     Event dates                           Event name  \
# 2552459           2020      19.01.2020        Big Bend 50 - Borderland 50M
# 2552462           2020      19.01.2020        Big Bend 50 - Borderland 50M
# 2552465           2020      19.01.2020        Big Bend 50 - Borderland 50M
# 2552472           2020      19.01.2020        Big Bend 50 - Borderland 50M
# 2591396           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591418           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591430           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591434           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591441           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591444           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# 2591447           2020      14.03.2020     Bel Monte 50 Mile Endurance Run
# ...

# %%
df2=df2.dropna()

# %%
df2.shape
# Out:
# (5657, 10)

# %%
df2[df2.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, Athlete_age]
# Index: []

# %%
df2.reset_index(drop=True)
# Out:
#       Year of event Event dates                  Event name  \
# 0              2020  01.02.2020  Elephant Mountain 50 Mile
# 1              2020  01.02.2020  Elephant Mountain 50 Mile
# 2              2020  01.02.2020  Elephant Mountain 50 Mile
# 3              2020  01.02.2020  Elephant Mountain 50 Mile
# 4              2020  01.02.2020  Elephant Mountain 50 Mile
# ...             ...         ...                         ...
# 5652           2020  10.10.2020  Old Cascadia 50 Mile Race
# 5653           2020  10.10.2020  Old Cascadia 50 Mile Race
# 5654           2020  10.10.2020  Old Cascadia 50 Mile Race
# 5655           2020  10.10.2020  Old Cascadia 50 Mile Race
# 5656           2020  10.10.2020  Old Cascadia 50 Mile Race
#
#      Event distance/length  Event number of finishers Athlete performance  \
# 0                     50mi                         10             8:51:11
# 1                     50mi                         10            11:37:15
# ...

# %%
#fix types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# Athlete_age                  float64
# dtype: object

# %%
df2['Athlete_age']=df2['Athlete_age'].astype(int)
# Out:
# C:\Users\kaust\AppData\Local\Temp\ipykernel_11368\1032053658.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete_age']=df2['Athlete_age'].astype(int)

# %%
df2.dtypes
# Out:
# Year of event                 int64
# Event dates                  object
# Event name                   object
# Event distance/length        object
# Event number of finishers     int64
# Athlete performance          object
# Athlete gender               object
# Athlete average speed        object
# Athlete ID                    int64
# Athlete_age                   int32
# dtype: object

# %%
df2['Athlete average speed']=df2['Athlete average speed'].astype(float)
# Out:
# C:\Users\kaust\AppData\Local\Temp\ipykernel_11368\3320540426.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Athlete average speed']=df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# Athlete_age                    int32
# dtype: object

# %%
df2
# Out:
#          Year of event Event dates                  Event name  \
# 2542134           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542135           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542136           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542137           2020  01.02.2020  Elephant Mountain 50 Mile
# 2542138           2020  01.02.2020  Elephant Mountain 50 Mile
# ...                ...         ...                         ...
# 2757274           2020  10.10.2020  Old Cascadia 50 Mile Race
# 2757275           2020  10.10.2020  Old Cascadia 50 Mile Race
# 2757276           2020  10.10.2020  Old Cascadia 50 Mile Race
# 2757277           2020  10.10.2020  Old Cascadia 50 Mile Race
# 2757278           2020  10.10.2020  Old Cascadia 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10             8:51:11
# ...

# %%
df2 = df2.rename(columns = {
    'year': 'Year',
    'race_day' : 'Race day' 
})

# %%
df2.head(5)
# Out:
#          Year    Race day                       Event name  \
# 2542134  2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542135  2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542136  2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542137  2020  01.02.2020  Elephant Mountain 50 Mile (USA)
# 2542138  2020  01.02.2020  Elephant Mountain 50 Mile (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2542134                  50mi                         10           8:51:11 h
# 2542135                  50mi                         10          11:37:15 h
# 2542136                  50mi                         10          11:59:00 h
# 2542137                  50mi                         10          12:04:40 h
# 2542138                  50mi                         10          12:26:20 h
#
#             Athlete club Athlete country  Athlete year of birth  \
# 2542134     *Phoenix, AZ             USA                 1987.0
# ...

# %%
df3=df2[['Race day']]

# %%
df3.head(5)
# Out:
#            Race day
# 2542134  01.02.2020
# 2542135  01.02.2020
# 2542136  01.02.2020
# 2542137  01.02.2020
# 2542138  01.02.2020

# %%
#charts and graphs

# %%
sns.histplot(df2['Event number of finishers'])
# Out:
# C:\Users\kaust\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Event number of finishers', ylabel='Count'>

# %%
sns.histplot(df2, x='Event number of finishers',hue = 'Athlete gender')
# Out:
# C:\Users\kaust\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Event number of finishers', ylabel='Count'>

# %%
sns.displot(data=df2, x='Event number of finishers', hue='Athlete gender')
# Out:
# C:\Users\kaust\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df2['Event distance/length'] = pd.to_numeric(df2['Event distance/length'], errors='coerce')
df2['Athlete average speed'] = pd.to_numeric(df2['Athlete average speed'], errors='coerce')
df2.dropna(subset=['Event distance/length', 'Athlete average speed'], inplace=True)

if df2['Event distance/length'].empty or df2['Athlete average speed'].empty:
    print("One or both of the columns are empty after data cleaning.")
else:
    sns.violinplot(data=df2, x='Event distance/length', y='Athlete average speed', hue='Athlete gender')
# Out:
# One or both of the columns are empty after data cleaning.
